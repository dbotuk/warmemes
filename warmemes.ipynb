# %% [markdown]
# # Import libraries

# %%
import os
import pandas as pd
import requests
import string

from dotenv import load_dotenv
from io import BytesIO
from lxml import html
from PIL import Image
from tqdm import tqdm

# %% [markdown]
# # Define Dataframe Structure

# %%
columns = ['meme_id', 'image_path', 'month', 'year', 'history', 'event', 'meme', 'creator', 'tags', 'related']
memes_df = pd.DataFrame(columns=columns)

# %% [markdown]
# # Define Scrapping Functionality

# %%
def get_meme_id(url):
    return url.split('/')[-2]


def save_image(name, tree, headers):
    image_url = tree.xpath('//div[contains(@class, "mm-img-item")]//img/@src')[0]
    image_format = image_url.split("/")[-1].split(".")[-1]
    image_path = os.path.join('images', name + '.' + image_format)

    response = requests.get(image_url, headers=headers)
    image = Image.open(BytesIO(response.content))
    image.save(image_path)
    
    return image_path


def get_date(url):
    date = url.split('/')[-2].split('-')
    
    month, year = None, None
    if len(date) == 2:
        month, year = date
    elif len(date) == 1: # some of urls contain only month
        month = date[0]
    
    return month, year


def get_info(tree, field):
    if tree.xpath(f'//div[contains(@class, "mm-info-title") and contains(text(), "{field}")]/following-sibling::a[contains(@class, "btn")]'):
        return
    info = ' '.join(tree.xpath(f'//div[contains(@class, "mm-info-title") and contains(text(), "{field}")]/..//text()'))
    
    # info also contains field name, so we remove it
    if len(info.split(field)) > 1:
        return info.split(field)[1].strip()
    else:
        return

    
def get_related_memes(tree):
    return [get_meme_id(meme) for meme in tree.xpath('//div[contains(@class, "memes-list")]//a/@href')]

# %% [markdown]
# # Set Up Scrapping Configuration

# %%
website_url = "https://warmemes.com.ua/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"
}
response = requests.get(website_url, headers=headers)

tree = html.fromstring(response.content)

# %% [markdown]
# # Data Scrapping

# %%
months_urls = tree.xpath('//div[contains(@class, "home-main")]//ul[contains(@class, "monthes-list")]//a/@href')

for months_url in tqdm(months_urls):
    response = requests.get(months_url, headers=headers)
    tree = html.fromstring(response.content)
    meme_urls = tree.xpath('//div[contains(@class, "meme")]/a/@href')
    
    month, year = get_date(months_url)
    
    for url in meme_urls:
        response = requests.get(url, headers=headers)
        tree = html.fromstring(response.content)

        row = {}
        
        row['month'] = month
        row['year'] = year

        meme_id = get_meme_id(url)
        row['meme_id'] = meme_id

        image_path = save_image(meme_id, tree, headers)
        row['image_path'] = image_path

        related = get_related_memes(tree)
        row['related'] = related
        
        event = get_info(tree, 'Event:')
        row['event'] = event
        
        meme = get_info(tree, 'Meme:')
        row['meme'] = meme
        
        history = get_info(tree, "Meme’s history:")
        row['history'] = history
        
        creator = get_info(tree, 'Creator:')
        row['creator'] = creator
        
        tags = get_info(tree, 'Tags:')
        row['tags'] = tags

        row = pd.DataFrame([row])
        if memes_df.empty:
            memes_df = row
        else:
            memes_df = pd.concat([memes_df, row], ignore_index=True)
# Out:
# 100%|███████████████████████████████████████████| 34/34 [04:03<00:00,  7.17s/it]

# %%
memes_df
# Out:
#         month  year                     meme_id  \
# 0    february  2022                         war
# 1    february  2022               war-and-peace
# 2    february  2022  scale-of-ukrainian-heroism
# 3    february  2022               ghost-of-kyiv
# 4    february  2022             sunflower-seeds
# ..        ...   ...                         ...
# 219   october  2024                      nafo-2
# 220   october  2024             nato-or-nuclear
# 221   october  2024                    last-day
# 222  november  2024                    700000-2
# 223  november  2024                      700000
#
#                                 image_path  \
# 0                           images/war.jpg
# 1                 images/war-and-peace.png
# 2    images/scale-of-ukrainian-heroism.jpg
# 3                 images/ghost-of-kyiv.png
# 4              images/sunflower-seeds.webp
# ..                                     ...
# 219                      images/nafo-2.jpg
# 220             images/nato-or-nuclear.jpg
# 221                    images/last-day.jpg
# 222                    images/700000-2.jpg
# 223                      images/700000.jpg
#
#                                                related  \
# 0           [february, war-and-peace, 100-days-of-war]
# 1                     [february, 100-days-of-war, war]
# 2    [every-morning, sleep-well-little-tank, day-16...
# 3    [kyiv-is-angry, meteor-in-kyiv, attacks-on-kyi...
# 4                                                   []
# ..                                                 ...
# 219  [fundraising-for-nuclear, dirty-bomb, nato-or-...
# 220  [finland-nato, proton, nafo-2, nato, dirty-bom...
# 221                                                 []
# 222                                                 []
# 223  [how-it-started, 250-000, russian-mobilization...
#
#                                                  event  \
# 0                        Putin declared war on Ukraine
# 1    Russian authorities forbade to call Russian in...
# 2    After several days, it became evident that Ukr...
# 3    Russia was unable to establish air superiority...
# 4    A Ukrainian woman told Russian soldier: ‘Put s...
# ..                                                 ...
# 219                                               None
# 220  Zelensky told NATO members that Ukraine must e...
# 221  Ukraine adopted the law to cancel Daylight Sav...
# 222                                               None
# 223  700,000 Russian soldiers counted as combat losses
#
#                            meme  \
# 0                           War
# 1                 War and peace
# 2    Scale of Ukrainian heroism
# 3                 Ghost of Kyiv
# 4               Sunflower seeds
# ..                          ...
# 219                        NAFO
# 220             NATO or nuclear
# 221                    Last day
# 222                      700000
# 223                      700000
#
#                                                history creator  \
# 0                                                 None    None
# 1    Probably, the famous Leo Tolstoy's novel "War ...    None
# 2    This meme is comparing the size of two countri...    None
# 3    Ghost of Kyiv is a nickname given to a mythica...    None
# 4    A viral video appeared showing a Ukrainian wom...    None
# ..                                                 ...     ...
# 219                                               None    None
# 220                                               None    None
# 221  The text says "The daylight savings switch wil...    None
# 222                                               None    None
# 223                                               None    None
#
#                                                   tags
# 0                                        #2022 ,  #war
# 1                  #war ,  #special military operation
# 2                   #russia ,  #resilience ,  #Ukraine
# 3    #Kyiv ,  #aircraft ,  #airplanes ,  #Ghost of ...
# 4                   #sunflower ,  #seeds ,  #occupiers
# ..                                                 ...
# 219                                  #nuclear ,  #NAFO
# 220                                  #nuclear ,  #NATO
# 221                                   #daylight saving
# 222                           #700000 ,  #dead russian
# 223                              #dead russian ,  #KIA
#
# [224 rows x 10 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Let's search for duplicates within meme id

# %%
duplicates = memes_df.meme_id.duplicated(keep=False)
memes_df[duplicates]
# Out:
#     month  year                meme_id                         image_path  \
# 120   may  2023  prigozhin_and_budanov  images/prigozhin_and_budanov.jpeg
# 135  june  2023  prigozhin_and_budanov  images/prigozhin_and_budanov.jpeg
#
#                                                related  \
# 120  [shark, popcorn, smiling, forrest-gump, breaki...
# 135  [ride-not-ammunition, breaking, forrest-gump, ...
#
#                                                  event                   meme  \
# 120  Yevgeny Prigozhin with his Wagner mercenaries ...  Prigozhin and Budanov
# 135  Yevgeny Prigozhin with his Wagner mercenaries ...  Prigozhin and Budanov
#
#                                                history creator  \
# 120  A meme shows an imaginary dialogue between Pri...    None
# 135  A meme shows an imaginary dialogue between Pri...    None
#
#                                   tags
# 120  #Budanov ,  #Prigozhin ,  #Wagner
# 135  #Budanov ,  #Prigozhin ,  #Wagner

# %% [markdown]
# As we can see it is the same meme, present both in May and June. Let's leave only one.

# %%
memes_df = memes_df.drop_duplicates(subset='meme_id')

# %% [markdown]
# There are many missing fields, let's set it like an empty string.

# %%
memes_df = memes_df.fillna('')

# %% [markdown]
# # Data Preparation

# %% [markdown]
# For further comfortable investigation let's map tags to a list of words.

# %%
memes_df.tags = memes_df.tags.apply(lambda row: list(map(str.strip, row.replace('#', '').split(','))) if row else [])
memes_df
# Out:
#         month  year                     meme_id  \
# 0    february  2022                         war
# 1    february  2022               war-and-peace
# 2    february  2022  scale-of-ukrainian-heroism
# 3    february  2022               ghost-of-kyiv
# 4    february  2022             sunflower-seeds
# ..        ...   ...                         ...
# 219   october  2024                      nafo-2
# 220   october  2024             nato-or-nuclear
# 221   october  2024                    last-day
# 222  november  2024                    700000-2
# 223  november  2024                      700000
#
#                                 image_path  \
# 0                           images/war.jpg
# 1                 images/war-and-peace.png
# 2    images/scale-of-ukrainian-heroism.jpg
# 3                 images/ghost-of-kyiv.png
# 4              images/sunflower-seeds.webp
# ..                                     ...
# 219                      images/nafo-2.jpg
# 220             images/nato-or-nuclear.jpg
# 221                    images/last-day.jpg
# 222                    images/700000-2.jpg
# 223                      images/700000.jpg
#
#                                                related  \
# 0           [february, war-and-peace, 100-days-of-war]
# 1                     [february, 100-days-of-war, war]
# 2    [every-morning, sleep-well-little-tank, day-16...
# 3    [kyiv-is-angry, meteor-in-kyiv, attacks-on-kyi...
# 4                                                   []
# ..                                                 ...
# 219  [fundraising-for-nuclear, dirty-bomb, nato-or-...
# 220  [finland-nato, proton, nafo-2, nato, dirty-bom...
# 221                                                 []
# 222                                                 []
# 223  [how-it-started, 250-000, russian-mobilization...
#
#                                                  event  \
# 0                        Putin declared war on Ukraine
# 1    Russian authorities forbade to call Russian in...
# 2    After several days, it became evident that Ukr...
# 3    Russia was unable to establish air superiority...
# 4    A Ukrainian woman told Russian soldier: ‘Put s...
# ..                                                 ...
# 219
# 220  Zelensky told NATO members that Ukraine must e...
# 221  Ukraine adopted the law to cancel Daylight Sav...
# 222
# 223  700,000 Russian soldiers counted as combat losses
#
#                            meme  \
# 0                           War
# 1                 War and peace
# 2    Scale of Ukrainian heroism
# 3                 Ghost of Kyiv
# 4               Sunflower seeds
# ..                          ...
# 219                        NAFO
# 220             NATO or nuclear
# 221                    Last day
# 222                      700000
# 223                      700000
#
#                                                history creator  \
# 0
# 1    Probably, the famous Leo Tolstoy's novel "War ...
# 2    This meme is comparing the size of two countri...
# 3    Ghost of Kyiv is a nickname given to a mythica...
# 4    A viral video appeared showing a Ukrainian wom...
# ..                                                 ...     ...
# 219
# 220
# 221  The text says "The daylight savings switch wil...
# 222
# 223
#
#                                            tags
# 0                                   [2022, war]
# 1             [war, special military operation]
# 2                 [russia, resilience, Ukraine]
# 3    [Kyiv, aircraft, airplanes, Ghost of Kyiv]
# 4                 [sunflower, seeds, occupiers]
# ..                                          ...
# 219                             [nuclear, NAFO]
# 220                             [nuclear, NATO]
# 221                           [daylight saving]
# 222                      [700000, dead russian]
# 223                         [dead russian, KIA]
#
# [223 rows x 10 columns]

# %% [markdown]
# Let's save fields with lists as a string with `;` separator.

# %%
memes_df['related'] = memes_df.related.apply(lambda row: ';'.join(row))
memes_df['tags'] = memes_df.tags.apply(lambda row: ';'.join(row))
memes_df
# Out:
#         month  year                     meme_id  \
# 0    february  2022                         war
# 1    february  2022               war-and-peace
# 2    february  2022  scale-of-ukrainian-heroism
# 3    february  2022               ghost-of-kyiv
# 4    february  2022             sunflower-seeds
# ..        ...   ...                         ...
# 219   october  2024                      nafo-2
# 220   october  2024             nato-or-nuclear
# 221   october  2024                    last-day
# 222  november  2024                    700000-2
# 223  november  2024                      700000
#
#                                 image_path  \
# 0                           images/war.jpg
# 1                 images/war-and-peace.png
# 2    images/scale-of-ukrainian-heroism.jpg
# 3                 images/ghost-of-kyiv.png
# 4              images/sunflower-seeds.webp
# ..                                     ...
# 219                      images/nafo-2.jpg
# 220             images/nato-or-nuclear.jpg
# 221                    images/last-day.jpg
# 222                    images/700000-2.jpg
# 223                      images/700000.jpg
#
#                                                related  \
# 0               february;war-and-peace;100-days-of-war
# 1                         february;100-days-of-war;war
# 2    every-morning;sleep-well-little-tank;day-160;r...
# 3    kyiv-is-angry;meteor-in-kyiv;attacks-on-kyiv;a...
# 4
# ..                                                 ...
# 219  fundraising-for-nuclear;dirty-bomb;nato-or-nuc...
# 220  finland-nato;proton;nafo-2;nato;dirty-bomb;fun...
# 221
# 222
# 223  how-it-started;250-000;russian-mobilization;50...
#
#                                                  event  \
# 0                        Putin declared war on Ukraine
# 1    Russian authorities forbade to call Russian in...
# 2    After several days, it became evident that Ukr...
# 3    Russia was unable to establish air superiority...
# 4    A Ukrainian woman told Russian soldier: ‘Put s...
# ..                                                 ...
# 219
# 220  Zelensky told NATO members that Ukraine must e...
# 221  Ukraine adopted the law to cancel Daylight Sav...
# 222
# 223  700,000 Russian soldiers counted as combat losses
#
#                            meme  \
# 0                           War
# 1                 War and peace
# 2    Scale of Ukrainian heroism
# 3                 Ghost of Kyiv
# 4               Sunflower seeds
# ..                          ...
# 219                        NAFO
# 220             NATO or nuclear
# 221                    Last day
# 222                      700000
# 223                      700000
#
#                                                history creator  \
# 0
# 1    Probably, the famous Leo Tolstoy's novel "War ...
# 2    This meme is comparing the size of two countri...
# 3    Ghost of Kyiv is a nickname given to a mythica...
# 4    A viral video appeared showing a Ukrainian wom...
# ..                                                 ...     ...
# 219
# 220
# 221  The text says "The daylight savings switch wil...
# 222
# 223
#
#                                       tags
# 0                                 2022;war
# 1           war;special military operation
# 2                russia;resilience;Ukraine
# 3    Kyiv;aircraft;airplanes;Ghost of Kyiv
# 4                sunflower;seeds;occupiers
# ..                                     ...
# 219                           nuclear;NAFO
# 220                           nuclear;NATO
# 221                        daylight saving
# 222                    700000;dead russian
# 223                       dead russian;KIA
#
# [223 rows x 10 columns]

# %% [markdown]
# # Data Translation

# %% [markdown]
# We are interested in Ukrainian representation, so let's translated field with text content to Ukrainian using Google Translation API.
#
# `GOOGLE_API_KEY` is saved inside `.env`.

# %%
load_dotenv()

google_api_key = os.getenv("GOOGLE_API_KEY")
url = f"https://translation.googleapis.com/language/translate/v2"

def translate_text(text, api_key, target_lang="uk"):
    params = {
        "q": text,
        "target": target_lang,
        "key": api_key
    }

    response = requests.post(url, data=params)
    return response.json()["data"]["translations"][0]["translatedText"]

# %% [markdown]
# Target fields are `event`, `meme`, `history` and `tags`.

# %%
memes_df['event_ua'] = memes_df.event.apply(lambda row: translate_text(row, google_api_key) if row else '')
memes_df['meme_ua'] = memes_df.meme.apply(lambda row: translate_text(row, google_api_key) if row else '')
memes_df['history_ua'] = memes_df.history.apply(lambda row: translate_text(row, google_api_key) if row else '')
memes_df['tags_ua'] = memes_df.tags.apply(lambda row: ';'.join([translate_text(tag, google_api_key) for tag in row.split(';')]) if row else [])

# %%
memes_df
# Out:
#         month  year                     meme_id  \
# 0    february  2022                         war
# 1    february  2022               war-and-peace
# 2    february  2022  scale-of-ukrainian-heroism
# 3    february  2022               ghost-of-kyiv
# 4    february  2022             sunflower-seeds
# ..        ...   ...                         ...
# 219   october  2024                      nafo-2
# 220   october  2024             nato-or-nuclear
# 221   october  2024                    last-day
# 222  november  2024                    700000-2
# 223  november  2024                      700000
#
#                                 image_path  \
# 0                           images/war.jpg
# 1                 images/war-and-peace.png
# 2    images/scale-of-ukrainian-heroism.jpg
# 3                 images/ghost-of-kyiv.png
# 4              images/sunflower-seeds.webp
# ..                                     ...
# 219                      images/nafo-2.jpg
# 220             images/nato-or-nuclear.jpg
# 221                    images/last-day.jpg
# 222                    images/700000-2.jpg
# 223                      images/700000.jpg
#
#                                                related  \
# 0               february;war-and-peace;100-days-of-war
# 1                         february;100-days-of-war;war
# 2    every-morning;sleep-well-little-tank;day-160;r...
# 3    kyiv-is-angry;meteor-in-kyiv;attacks-on-kyiv;a...
# 4
# ..                                                 ...
# 219  fundraising-for-nuclear;dirty-bomb;nato-or-nuc...
# 220  finland-nato;proton;nafo-2;nato;dirty-bomb;fun...
# 221
# 222
# 223  how-it-started;250-000;russian-mobilization;50...
#
#                                                  event  \
# 0                        Putin declared war on Ukraine
# 1    Russian authorities forbade to call Russian in...
# 2    After several days, it became evident that Ukr...
# 3    Russia was unable to establish air superiority...
# 4    A Ukrainian woman told Russian soldier: ‘Put s...
# ..                                                 ...
# 219
# 220  Zelensky told NATO members that Ukraine must e...
# 221  Ukraine adopted the law to cancel Daylight Sav...
# 222
# 223  700,000 Russian soldiers counted as combat losses
#
#                            meme  \
# 0                           War
# 1                 War and peace
# 2    Scale of Ukrainian heroism
# 3                 Ghost of Kyiv
# 4               Sunflower seeds
# ..                          ...
# 219                        NAFO
# 220             NATO or nuclear
# 221                    Last day
# 222                      700000
# 223                      700000
#
#                                                history creator  \
# 0
# 1    Probably, the famous Leo Tolstoy's novel "War ...
# 2    This meme is comparing the size of two countri...
# 3    Ghost of Kyiv is a nickname given to a mythica...
# 4    A viral video appeared showing a Ukrainian wom...
# ..                                                 ...     ...
# 219
# 220
# 221  The text says "The daylight savings switch wil...
# 222
# 223
#
#                                       tags  \
# 0                                 2022;war
# 1           war;special military operation
# 2                russia;resilience;Ukraine
# 3    Kyiv;aircraft;airplanes;Ghost of Kyiv
# 4                sunflower;seeds;occupiers
# ..                                     ...
# 219                           nuclear;NAFO
# 220                           nuclear;NATO
# 221                        daylight saving
# 222                    700000;dead russian
# 223                       dead russian;KIA
#
#                                               event_ua  \
# 0                         Путін оголосив війну Україні
# 1    Російська влада заборонила називати російське ...
# 2    Через кілька днів стало зрозуміло, що Україна ...
# 3    Росія не змогла встановити перевагу в повітрі ...
# 4    Українка сказала російському солдату: «Поклади...
# ..                                                 ...
# 219
# 220  Зеленський заявив членам НАТО, що Україна має ...
# 221  В Україні ухвалили закон про скасування перехо...
# 222
# 223  Бойовими втратами зараховано 700 тисяч російсь...
#
#                             meme_ua  \
# 0                             Війна
# 1                       Війна і мир
# 2    Масштаби українського героїзму
# 3                      Привид Києва
# 4                 Насіння соняшнику
# ..                              ...
# 219                            НАФО
# 220                  НАТО чи ядерна
# 221                   Останній день
# 222                          700000
# 223                          700000
#
#                                             history_ua  \
# 0
# 1    Мабуть, відомий роман Льва Толстого «Війна і м...
# 2    Цей мем порівнює розміри двох країн: України т...
# 3    Привид Києва — це прізвисько, яке дали міфічно...
# 4    З&#39;явилося вірусне відео, на якому українка...
# ..                                                 ...
# 219
# 220
# 221  У тексті сказано: «Перехід на літній та зимови...
# 222
# 223
#
#                             tags_ua
# 0                    2022 рік;війни
# 1      війни;військова спецоперація
# 2           росія;стійкість;Україна
# 3    Київ;літак;літаки;Привид Києва
# 4         соняшник;насіння;окупанти
# ..                              ...
# 219                    ядерний;НАФО
# 220                    ядерний;НАТО
# 221                      літній час
# 222         700000;мертвий росіянин
# 223            мертвий росіянин;KIA
#
# [223 rows x 14 columns]

# %%
memes_df.to_csv("warmemes.csv", index=False)
